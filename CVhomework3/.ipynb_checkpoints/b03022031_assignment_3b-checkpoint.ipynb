# %%
import os
import cv2
import numpy as np
import pickle
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
import matplotlib.pyplot as plt

def get_data_from_file(train_file):
    train_data = []
    with open('train_list.txt') as fp:
        for line in fp:
            a=line.strip().split("/")
            img_path=a[0]+"\\"+a[1]
            try:
                img = cv2.imread(img_path)
                #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                img_resized = cv2.resize(img, (48, 48))
                
                if 'Cat' in img_path:
                    label = 0
                elif 'Dog' in img_path:
                    label = 1

                train_data.append([img_resized,label])
            except:
                print ('error message')
    return train_data
      

def get_image_and_label(train_data):
    listname=[]
    listindex=[]
    for i in range(len(train_data)):
        listname.append(train_data[i][0])
        listindex.append(train_data[i][1])
        
    listname=np.array(listname)
    listindex=np.array(listindex)
    print(listname.shape)
    return listname,listindex
def assignment3b_1():
    train_file = 'train_list.txt'
    test_file = 'test_list.txt'
    
    train_data = get_data_from_file(train_file)
    X_train, Y_train = get_image_and_label(train_data)
    
    test_data = get_data_from_file(test_file)    
    X_test, Y_test = get_image_and_label(test_data)
    
    save_path = 'dogs_cats.pkl' 
    print('Saving to', save_path)
    data = {}
    data['X_train'] = X_train
    data['Y_train'] = Y_train
    data['X_test'] = X_test
    data['Y_test'] = Y_test
    pickle.dump(data, open(save_path, 'wb'))
    

def assignment3b_2():
    data = pickle.load(open("dogs_cats.pkl","rb"))
    X_train, Y_train, X_test, Y_test = data["X_train"], data["Y_train"], data["X_test"], data["Y_test"]
    X_train = X_train / 255.0
    X_test = X_test / 255.0
    model=build_model ()
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    
    
    history=model.fit(X_train, Y_train ,verbose = 2, epochs=50 , batch_size = 128  )
    plt.plot(history.history['loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()
    
    test_loss, test_acc = model.evaluate(X_test, Y_test)
   
        
    '''
    for i in range(reg.shape[0]):
        if reg[i]>0.5:
            prediction.append(1)
        else:
            prediction.append(0)
    '''
    

def assignment3b_3():
    data = pickle.load(open("dogs_cats.pkl","rb"))
    X_train, Y_train, X_test, Y_test = data["X_train"], data["Y_train"], data["X_test"], data["Y_test"]
    X_train = X_train / 255.0
    X_test = X_test / 255.0
    
    model = keras.Sequential([
    keras.layers.Flatten(input_shape=(48,48,3)),
    keras.layers.Dense(256, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(1, activation='linear')])
        
    
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'] )
    history=model.fit(X_train, Y_train , epochs=50 , batch_size = 128 )
    plt.plot(history.history['loss'])
    
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    
    plt.show()
    prediction=[]
    reg = model.predict(X_test).squeeze()
    test_loss, test_acc = model.evaluate(X_test, Y_test)
    predictions = np.empty((reg.shape[0]))
    for i in range(reg.shape[0]):
        if (reg[i]>0.5):
            predictions[i]=1
        else:
            predictions[i]=0
    acc=len(predictions[predictions==Y_test]) /len(Y_test)
    
    print("test_accurancy: %.4f" %acc)
        
  # enter your code here

def build_model():
    model = keras.Sequential([
    keras.layers.Flatten(input_shape=(48,48,3)),
    keras.layers.Dense(256, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(2, activation=tf.nn.softmax)])
    model.summary()
    return model    
data_dir = 'PetImages'
img_size = 48

if __name__ == '__main__':
    assignment3b_1()
# Out:
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# (4986, 48, 48, 3)
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# error message
# (4986, 48, 48, 3)
# Saving to dogs_cats.pkl

# %%
assignment3b_2()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 6912)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1769728
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 1,802,882
# Trainable params: 1,802,882
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 39/39 - 2s - loss: 1.1956 - accuracy: 0.5104
# Epoch 2/50
# 39/39 - 0s - loss: 0.6999 - accuracy: 0.5471
# Epoch 3/50
# 39/39 - 0s - loss: 0.6973 - accuracy: 0.5463
# Epoch 4/50
# 39/39 - 0s - loss: 0.7125 - accuracy: 0.5489
# Epoch 5/50
# 39/39 - 0s - loss: 0.6865 - accuracy: 0.5706
# Epoch 6/50
# 39/39 - 0s - loss: 0.6508 - accuracy: 0.6115
# Epoch 7/50
# 39/39 - 0s - loss: 0.6605 - accuracy: 0.6007
# Epoch 8/50
# 39/39 - 0s - loss: 0.6563 - accuracy: 0.6131
# Epoch 9/50
# 39/39 - 0s - loss: 0.6349 - accuracy: 0.6350
# Epoch 10/50
# 39/39 - 0s - loss: 0.6371 - accuracy: 0.6416
# Epoch 11/50
# 39/39 - 0s - loss: 0.6375 - accuracy: 0.6290
# Epoch 12/50
# 39/39 - 0s - loss: 0.6183 - accuracy: 0.6532
# Epoch 13/50
# 39/39 - 0s - loss: 0.6285 - accuracy: 0.6436
# Epoch 14/50
# 39/39 - 0s - loss: 0.6334 - accuracy: 0.6312
# Epoch 15/50
# 39/39 - 0s - loss: 0.6157 - accuracy: 0.6623
# Epoch 16/50
# 39/39 - 0s - loss: 0.6220 - accuracy: 0.6448
# Epoch 17/50
# 39/39 - 0s - loss: 0.6014 - accuracy: 0.6741
# Epoch 18/50
# 39/39 - 0s - loss: 0.6242 - accuracy: 0.6442
# Epoch 19/50
# 39/39 - 0s - loss: 0.5999 - accuracy: 0.6771
# Epoch 20/50
# 39/39 - 0s - loss: 0.5875 - accuracy: 0.6833
# Epoch 21/50
# 39/39 - 0s - loss: 0.5987 - accuracy: 0.6721
# Epoch 22/50
# 39/39 - 0s - loss: 0.6174 - accuracy: 0.6532
# Epoch 23/50
# 39/39 - 0s - loss: 0.5951 - accuracy: 0.6709
# Epoch 24/50
# 39/39 - 0s - loss: 0.6071 - accuracy: 0.6667
# Epoch 25/50
# 39/39 - 0s - loss: 0.5969 - accuracy: 0.6731
# Epoch 26/50
# 39/39 - 0s - loss: 0.5843 - accuracy: 0.6827
# Epoch 27/50
# 39/39 - 0s - loss: 0.5841 - accuracy: 0.6883
# Epoch 28/50
# 39/39 - 0s - loss: 0.5950 - accuracy: 0.6753
# Epoch 29/50
# 39/39 - 0s - loss: 0.5799 - accuracy: 0.6851
# Epoch 30/50
# 39/39 - 0s - loss: 0.5917 - accuracy: 0.6719
# Epoch 31/50
# 39/39 - 0s - loss: 0.5747 - accuracy: 0.6947
# Epoch 32/50
# 39/39 - 0s - loss: 0.5540 - accuracy: 0.7142
# Epoch 33/50
# 39/39 - 0s - loss: 0.5708 - accuracy: 0.6955
# Epoch 34/50
# 39/39 - 0s - loss: 0.5526 - accuracy: 0.7074
# Epoch 35/50
# 39/39 - 0s - loss: 0.5257 - accuracy: 0.7290
# Epoch 36/50
# 39/39 - 0s - loss: 0.5394 - accuracy: 0.7176
# Epoch 37/50
# 39/39 - 0s - loss: 0.5268 - accuracy: 0.7298
# Epoch 38/50
# 39/39 - 0s - loss: 0.5424 - accuracy: 0.7180
# Epoch 39/50
# 39/39 - 0s - loss: 0.5282 - accuracy: 0.7244
# Epoch 40/50
# 39/39 - 0s - loss: 0.4957 - accuracy: 0.7587
# Epoch 41/50
# 39/39 - 0s - loss: 0.5924 - accuracy: 0.6879
# Epoch 42/50
# 39/39 - 0s - loss: 0.5144 - accuracy: 0.7443
# Epoch 43/50
# 39/39 - 0s - loss: 0.4822 - accuracy: 0.7625
# Epoch 44/50
# 39/39 - 0s - loss: 0.4884 - accuracy: 0.7571
# Epoch 45/50
# 39/39 - 0s - loss: 0.4918 - accuracy: 0.7525
# Epoch 46/50
# 39/39 - 0s - loss: 0.4564 - accuracy: 0.7790
# Epoch 47/50
# 39/39 - 0s - loss: 0.4775 - accuracy: 0.7641
# Epoch 48/50
# 39/39 - 0s - loss: 0.4447 - accuracy: 0.7854
# Epoch 49/50
# 39/39 - 0s - loss: 0.4412 - accuracy: 0.7890
# Epoch 50/50
# 39/39 - 0s - loss: 0.4477 - accuracy: 0.7854
# 156/156 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.7872

# %%
assignment3b_3()
# Out:
# Epoch 1/50
# 39/39 [==============================] - 1s 10ms/step - loss: 7.1077 - accuracy: 0.4822
# Epoch 2/50
# 39/39 [==============================] - 0s 12ms/step - loss: 0.2995 - accuracy: 0.5176
# Epoch 3/50
# 39/39 [==============================] - 0s 10ms/step - loss: 0.2678 - accuracy: 0.5321
# Epoch 4/50
# 39/39 [==============================] - 0s 8ms/step - loss: 0.2613 - accuracy: 0.5463
# Epoch 5/50
# 39/39 [==============================] - 0s 9ms/step - loss: 0.2573 - accuracy: 0.5600
# Epoch 6/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2830 - accuracy: 0.5347
# Epoch 7/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2505 - accuracy: 0.5734
# Epoch 8/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2573 - accuracy: 0.5574
# Epoch 9/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2469 - accuracy: 0.5780
# Epoch 10/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2586 - accuracy: 0.5630: 0s - loss: 0.2491 - accuracy: 0.
# Epoch 11/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2549 - accuracy: 0.5720
# Epoch 12/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2482 - accuracy: 0.5860
# Epoch 13/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2677 - accuracy: 0.5527
# Epoch 14/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2400 - accuracy: 0.5961
# Epoch 15/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2384 - accuracy: 0.6033
# Epoch 16/50
# 39/39 [==============================] - 0s 8ms/step - loss: 0.3124 - accuracy: 0.5562
# Epoch 17/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2463 - accuracy: 0.5760
# Epoch 18/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2295 - accuracy: 0.6133
# Epoch 19/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2373 - accuracy: 0.6077
# Epoch 20/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2745 - accuracy: 0.5674
# Epoch 21/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2791 - accuracy: 0.5748
# Epoch 22/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2246 - accuracy: 0.6290
# Epoch 23/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2363 - accuracy: 0.6151
# Epoch 24/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2342 - accuracy: 0.6241
# Epoch 25/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2771 - accuracy: 0.5784
# Epoch 26/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2486 - accuracy: 0.5983
# Epoch 27/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2205 - accuracy: 0.6362
# Epoch 28/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2189 - accuracy: 0.6420
# Epoch 29/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2272 - accuracy: 0.6442
# Epoch 30/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2099 - accuracy: 0.6643
# Epoch 31/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2297 - accuracy: 0.6249
# Epoch 32/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2285 - accuracy: 0.6346
# Epoch 33/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.2084 - accuracy: 0.6733
# Epoch 34/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2525 - accuracy: 0.5981
# Epoch 35/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.6821
# Epoch 36/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.2105 - accuracy: 0.6701
# Epoch 37/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.2111 - accuracy: 0.6681
# Epoch 38/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1986 - accuracy: 0.6947
# Epoch 39/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1996 - accuracy: 0.6861
# Epoch 40/50
# 39/39 [==============================] - 0s 10ms/step - loss: 0.2008 - accuracy: 0.6875
# Epoch 41/50
# 39/39 [==============================] - 1s 14ms/step - loss: 0.2055 - accuracy: 0.6827
# Epoch 42/50
# 39/39 [==============================] - 0s 9ms/step - loss: 0.2232 - accuracy: 0.6566
# Epoch 43/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1901 - accuracy: 0.7064
# Epoch 44/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1889 - accuracy: 0.7154
# Epoch 45/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1977 - accuracy: 0.6955
# Epoch 46/50
# 39/39 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.7234
# Epoch 47/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1800 - accuracy: 0.7349
# Epoch 48/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1927 - accuracy: 0.7086
# Epoch 49/50
# 39/39 [==============================] - 0s 7ms/step - loss: 0.1946 - accuracy: 0.7004
# Epoch 50/50
# 39/39 [==============================] - 0s 6ms/step - loss: 0.1829 - accuracy: 0.7262
# 156/156 [==============================] - 0s 2ms/step - loss: 0.1824 - accuracy: 0.7222
# test_accurancy: 0.7222

# %%
sparse_categorical_crossentropy之收斂比較平滑準確率也較高mean squared error loss下降到一定程度之後就很難再下降了
